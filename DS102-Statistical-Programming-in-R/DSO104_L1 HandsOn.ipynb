# %%
import pandas as pd

# %%
FakeNews = pd.read_excel('/Users/clarkeashleigh/Downloads/FakeNews-2.xlsx')

# %%
FakeNews.head()
# Out:
#               when                                                url  \
# 0  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 1  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 2  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 3  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
# 4  before-nov-2016  http://wayback.archive.org/web/20161004072420i...
#
#                           tracker
# 0                     DoubleClick
# 1                      RevContent
# 2                     DoubleClick
# 3              Google Syndication
# 4  DoubleClick Ad Exchange-Seller

# %%
### Adding Colums

# %%
FakeNews ['StoryType'] = 'Fake'

# %%
### Remove when Column

# %%
FakeNews.drop (['when'], axis=1, inplace=True)

# %%
### Separate url

# %%
FakeNews_2 = FakeNews['url'].str.split ('_', expand=True).rename (columns = lambda x: "url" + str (x+1))

# %%
FakeNews_2.head()
# Out:
#                                               url1                     url2
# 0  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 1  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 2  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 3  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 4  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/

# %%
FakeNews_3 = pd.concat ([FakeNews, FakeNews_2], axis=1)

# %%
FakeNews_3.head()
# Out:
#                                                  url  \
# 0  http://wayback.archive.org/web/20161004072420i...
# 1  http://wayback.archive.org/web/20161004072420i...
# 2  http://wayback.archive.org/web/20161004072420i...
# 3  http://wayback.archive.org/web/20161004072420i...
# 4  http://wayback.archive.org/web/20161004072420i...
#
#                           tracker StoryType  \
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# 3              Google Syndication      Fake
# 4  DoubleClick Ad Exchange-Seller      Fake
#
#                                               url1                     url2
# 0  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 1  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 2  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# ...

# %%
### Put Domain together

# %%
FakeNews_3 ['Domain']= FakeNews_3 ["url1"] + "_" + FakeNews_3 ["url2"].map(str)

# %%
FakeNews_3.head()
# Out:
#                                                  url  \
# 0  http://wayback.archive.org/web/20161004072420i...
# 1  http://wayback.archive.org/web/20161004072420i...
# 2  http://wayback.archive.org/web/20161004072420i...
# 3  http://wayback.archive.org/web/20161004072420i...
# 4  http://wayback.archive.org/web/20161004072420i...
#
#                           tracker StoryType  \
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# 3              Google Syndication      Fake
# 4  DoubleClick Ad Exchange-Seller      Fake
#
#                                               url1                     url2  \
# 0  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 1  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 2  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# ...

# %%
FakeNews_3.drop(['url', 'url1', 'url2'], axis=1, inplace=True)

# %%
FakeNews_3.head()
# Out:
#                           tracker StoryType  \
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# 3              Google Syndication      Fake
# 4  DoubleClick Ad Exchange-Seller      Fake
#
#                                               Domain
# 0  http://wayback.archive.org/web/20161004072420i...
# 1  http://wayback.archive.org/web/20161004072420i...
# 2  http://wayback.archive.org/web/20161004072420i...
# 3  http://wayback.archive.org/web/20161004072420i...
# 4  http://wayback.archive.org/web/20161004072420i...

# %%
FakeNews_4 = FakeNews_3 [:10]

# %%
FakeNews_4
# Out:
#                                               url1                      url2
# 0  http://wayback.archive.org/web/20161004072420id   /http://alertchild.com/
# 1  http://wayback.archive.org/web/20161004072420id   /http://alertchild.com/
# 2  http://wayback.archive.org/web/20161004072420id   /http://alertchild.com/
# 3  http://wayback.archive.org/web/20161004072420id   /http://alertchild.com/
# 4  http://wayback.archive.org/web/20161004072420id   /http://alertchild.com/
# 5  http://wayback.archive.org/web/20161004072420id   /http://alertchild.com/
# 6  http://wayback.archive.org/web/20161004072420id   /http://alertchild.com/
# 7  http://wayback.archive.org/web/20161001155200id  /http://areyousleep.com/
# 8  http://wayback.archive.org/web/20161001155200id  /http://areyousleep.com/
# 9  http://wayback.archive.org/web/20161001155200id  /http://areyousleep.com/
